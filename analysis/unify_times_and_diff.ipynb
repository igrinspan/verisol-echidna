# %% [markdown]
# En los archivos de diff de Echidna, los datos se guardan con este formato:
#
# ```
#     obj = {
#         "Contract": contract,
#         "Test Limit": test_limit,
#         "Mode": mode,
#         "Node Difference": node_difference,
#         "Edge Difference": edge_difference,
#         "Reduce Combinations": option
#     }
# ```

# %% [markdown]
# Y para guardar el tiempo, se hace esto:
# ```
#     obj = {
#         "contract": contract,
#         "test_limit": test_limit,
#         "mode": mode,
#         "reduce combinations": reducing,
#         "time_in_s": time_taken_in_seconds,
#     }
# ```

# %% [markdown]
# Debería joinear mis jsons por contract, test_limit, mode, reduce combinations y que luego se agreguen node_difference, edge_difference y time_in_s.

# %% [markdown]
# ----

# %% [markdown]
# #### Función para mergear tiempos y diffs

# %%
import json
import pandas as pd

def merge_jsons(diff_json_file, times_json_file):

    with open(diff_json_file) as diff_json:
        diff = json.load(diff_json)

    with open(times_json_file) as times_json:
        times = json.load(times_json)
    
    diff_df = pd.DataFrame(diff)
    times_df = pd.DataFrame(times)

    # hago que los valores estén representados de la misma manera en las 2 tablas para que se pueda hacer bien el join
    times_df['mode'] = times_df['mode'].apply(lambda x: 'epa' if x == 'e' else 'states')
    times_df['reduce combinations'] = times_df['reduce combinations'].apply(lambda x: 'reduce_combinations' if x else 'not_reduce_combinations')

    # hago el join y descarto las columnas que se repitenn
    result = pd.merge(diff_df, times_df, how='inner', left_on=['Contract', 'Test Limit', 'Mode', 'Reduce Combinations'], right_on=['contract', 'test_limit', 'mode', 'reduce combinations'])

    # drop duplicated columns (contract, test_limit, mode and reduce combinations)
    result = result.drop(columns=['contract', 'test_limit', 'mode', 'reduce combinations'])

    return result

# %%
benchmark1 = merge_jsons('../results/diffs/diff_echidna_benchmark_1.json', '../results/times/echidna_benchmark1_times')
benchmark2 = merge_jsons('../results/diffs/diff_echidna_benchmark_2.json', '../results/times/echidna_benchmark2_times')

# %%
benchmark1.head(15)
# Out:
#                           Contract  Test Limit Mode  Node Difference
# 0                  BasicProvenance        1000  epa                0  \
# 1                  BasicProvenance       50000  epa                0
# 2                  BasicProvenance      500000  epa                0
# 3                  BasicProvenance        1000  epa               -1
# 4                  BasicProvenance       50000  epa                0
# 5                  BasicProvenance      500000  epa                0
# 6        DefectiveComponentCounter        1000  epa                0
# 7        DefectiveComponentCounter       50000  epa                0
# 8        DefectiveComponentCounter      500000  epa                0
# 9        DefectiveComponentCounter        1000  epa                0
# 10       DefectiveComponentCounter       50000  epa                0
# 11       DefectiveComponentCounter      500000  epa                0
# 12  FrequentFlyerRewardsCalculator        1000  epa                0
# 13  FrequentFlyerRewardsCalculator       50000  epa                0
# 14  FrequentFlyerRewardsCalculator      500000  epa                0
#
#     Edge Difference      Reduce Combinations  time_in_s
# 0                 0  not_reduce_combinations       3.62
# 1                 0  not_reduce_combinations      17.92
# 2                 0  not_reduce_combinations     146.37
# 3                -1      reduce_combinations       6.91
# 4                 0      reduce_combinations      21.96
# 5                 0      reduce_combinations     149.17
# 6                 0  not_reduce_combinations       3.94
# 7                 1  not_reduce_combinations      30.00
# 8                 1  not_reduce_combinations     260.11
# 9                 0      reduce_combinations       5.69
# 10                1      reduce_combinations      32.58
# 11                1      reduce_combinations     266.48
# 12               -1  not_reduce_combinations       4.69
# 13                0  not_reduce_combinations      53.64
# 14                0  not_reduce_combinations     475.09

# %%
benchmark2.head(15)
# Out:
#         Contract  Test Limit Mode  Node Difference  Edge Difference
# 0        Auction        1000  epa               -1              -10  \
# 1        Auction       50000  epa                0               -4
# 2        Auction      500000  epa                0               -2
# 3        Auction        1000  epa               -1               -7
# 4        Auction       50000  epa               -1               -7
# 5        Auction      500000  epa                0               -2
# 6   Crowdfunding        1000  epa               -1               -7
# 7   Crowdfunding       50000  epa               -1               -7
# 8   Crowdfunding      500000  epa                0               -2
# 9   Crowdfunding        1000  epa               -1               -7
# 10  Crowdfunding       50000  epa               -1               -5
# 11  Crowdfunding      500000  epa                0               -1
# 12  EPXCrowdsale        1000  epa               -3              -16
# 13  EPXCrowdsale       50000  epa               -1              -11
# 14  EPXCrowdsale      500000  epa               -1               -9
#
#         Reduce Combinations  time_in_s
# 0   not_reduce_combinations      14.71
# 1   not_reduce_combinations      41.96
# 2   not_reduce_combinations     291.16
# 3       reduce_combinations       7.52
# 4       reduce_combinations      17.41
# 5       reduce_combinations     126.89
# 6   not_reduce_combinations       8.61
# 7   not_reduce_combinations      37.02
# 8   not_reduce_combinations     296.77
# 9       reduce_combinations      10.94
# 10      reduce_combinations      31.60
# 11      reduce_combinations     229.73
# 12  not_reduce_combinations      91.62
# 13  not_reduce_combinations     443.36
# 14  not_reduce_combinations    3814.16

# %%
benchmark1['Reduce Combinations'] = benchmark1['Reduce Combinations'].apply(lambda x: 'True' if x == 'reduce_combinations' else 'False')
benchmark2['Reduce Combinations'] = benchmark2['Reduce Combinations'].apply(lambda x: 'True' if x == 'reduce_combinations' else 'False')

# %%
benchmark1.head(15)
# Out:
#                           Contract  Test Limit Mode  Node Difference
# 0                  BasicProvenance        1000  epa                0  \
# 1                  BasicProvenance       50000  epa                0
# 2                  BasicProvenance      500000  epa                0
# 3                  BasicProvenance        1000  epa               -1
# 4                  BasicProvenance       50000  epa                0
# 5                  BasicProvenance      500000  epa                0
# 6        DefectiveComponentCounter        1000  epa                0
# 7        DefectiveComponentCounter       50000  epa                0
# 8        DefectiveComponentCounter      500000  epa                0
# 9        DefectiveComponentCounter        1000  epa                0
# 10       DefectiveComponentCounter       50000  epa                0
# 11       DefectiveComponentCounter      500000  epa                0
# 12  FrequentFlyerRewardsCalculator        1000  epa                0
# 13  FrequentFlyerRewardsCalculator       50000  epa                0
# 14  FrequentFlyerRewardsCalculator      500000  epa                0
#
#     Edge Difference Reduce Combinations  time_in_s
# 0                 0               False       3.62
# 1                 0               False      17.92
# 2                 0               False     146.37
# 3                -1                True       6.91
# 4                 0                True      21.96
# 5                 0                True     149.17
# 6                 0               False       3.94
# 7                 1               False      30.00
# 8                 1               False     260.11
# 9                 0                True       5.69
# 10                1                True      32.58
# 11                1                True     266.48
# 12               -1               False       4.69
# 13                0               False      53.64
# 14                0               False     475.09

# %%
benchmark2.head(15)
# Out:
#         Contract  Test Limit Mode  Node Difference  Edge Difference
# 0        Auction        1000  epa               -1              -10  \
# 1        Auction       50000  epa                0               -4
# 2        Auction      500000  epa                0               -2
# 3        Auction        1000  epa               -1               -7
# 4        Auction       50000  epa               -1               -7
# 5        Auction      500000  epa                0               -2
# 6   Crowdfunding        1000  epa               -1               -7
# 7   Crowdfunding       50000  epa               -1               -7
# 8   Crowdfunding      500000  epa                0               -2
# 9   Crowdfunding        1000  epa               -1               -7
# 10  Crowdfunding       50000  epa               -1               -5
# 11  Crowdfunding      500000  epa                0               -1
# 12  EPXCrowdsale        1000  epa               -3              -16
# 13  EPXCrowdsale       50000  epa               -1              -11
# 14  EPXCrowdsale      500000  epa               -1               -9
#
#    Reduce Combinations  time_in_s
# 0                False      14.71
# 1                False      41.96
# 2                False     291.16
# 3                 True       7.52
# 4                 True      17.41
# 5                 True     126.89
# 6                False       8.61
# 7                False      37.02
# 8                False     296.77
# 9                 True      10.94
# 10                True      31.60
# 11                True     229.73
# 12               False      91.62
# 13               False     443.36
# 14               False    3814.16

# %%
# sort both dfs by test limit
benchmark1 = benchmark1.sort_values(by=['Mode', 'Test Limit', 'Contract'])
benchmark2 = benchmark2.sort_values(by=['Mode', 'Test Limit', 'Contract'])

# %%
benchmark1.head(15)
# Out:
#                           Contract  Test Limit Mode  Node Difference
# 0                  BasicProvenance        1000  epa                0  \
# 3                  BasicProvenance        1000  epa               -1
# 42            BasicProvenanceFixed        1000  epa                0
# 45            BasicProvenanceFixed        1000  epa               -1
# 6        DefectiveComponentCounter        1000  epa                0
# 9        DefectiveComponentCounter        1000  epa                0
# 48  DefectiveComponentCounterFixed        1000  epa                0
# 51  DefectiveComponentCounterFixed        1000  epa                0
# 12  FrequentFlyerRewardsCalculator        1000  epa                0
# 15  FrequentFlyerRewardsCalculator        1000  epa                0
# 21                 HelloBlockchain        1000  epa                0
# 18                 HelloBlockchain        1000  epa                0
# 57            HelloBlockchainFixed        1000  epa                0
# 54            HelloBlockchainFixed        1000  epa                0
# 24      RefrigeratedTransportation        1000  epa               -1
#
#     Edge Difference Reduce Combinations  time_in_s
# 0                 0               False       3.62
# 3                -1                True       6.91
# 42                0               False       4.11
# 45               -1                True       6.65
# 6                 0               False       3.94
# 9                 0                True       5.69
# 48                0               False       3.87
# 51                0                True       9.08
# 12               -1               False       4.69
# 15               -1                True       6.47
# 21                0                True       5.44
# 18                0               False       3.72
# 57                0                True       6.44
# 54                0               False       3.96
# 24               -3               False       6.02

# %%
benchmark2.head(15)
# Out:
#                            Contract  Test Limit Mode  Node Difference
# 0                           Auction        1000  epa               -1  \
# 3                           Auction        1000  epa               -1
# 87                     AuctionEnded        1000  epa               -1
# 84                     AuctionEnded        1000  epa               -1
# 90                  AuctionWithdraw        1000  epa               -3
# 93                  AuctionWithdraw        1000  epa               -3
# 6                      Crowdfunding        1000  epa               -1
# 9                      Crowdfunding        1000  epa               -1
# 54            CrowdfundingTime_Base        1000  epa               -2
# 57            CrowdfundingTime_Base        1000  epa                0
# 60     CrowdfundingTime_BaseBalance        1000  epa               -5
# 63     CrowdfundingTime_BaseBalance        1000  epa               -3
# 66  CrowdfundingTime_BaseBalanceFix        1000  epa               -3
# 69  CrowdfundingTime_BaseBalanceFix        1000  epa               -3
# 12                     EPXCrowdsale        1000  epa               -3
#
#     Edge Difference Reduce Combinations  time_in_s
# 0               -10               False      14.71
# 3                -7                True       7.52
# 87               -7                True       6.90
# 84              -11               False      43.46
# 90              -23               False      50.93
# 93              -22                True       6.79
# 6                -7               False       8.61
# 9                -7                True      10.94
# 54              -15               False      16.58
# 57               -7                True      10.86
# 60              -31               False     416.47
# 63              -26                True      47.22
# 66              -18               False     428.74
# 69              -15                True      61.09
# 12              -16               False      91.62

# %%
# transform df to csv and export
def export_as_csv(df, filename):
    df.to_csv(filename, index=False)

export_as_csv(benchmark1, '../results/echidna_benchmark1_merged.csv')
export_as_csv(benchmark2, '../results/echidna_benchmark2_merged.csv')
