# %% [markdown]
# ## Tiempos
#
# Hago una limpieza de los datos que obtuve sobre los tiempos de ejecución de cada contrato, con las distintas herramientas y configuraciones.
#
# Como resultado obtenemos dos dataframes distintas por cada benchmark (una para los tiempos en modo Epa y otra para los tiempos en modo States) y las mismas se exportan en formato .csv para poder visualizar y analizar los resultados. De esta manera se pueden comparar los tiempos de cada herramienta.
#
# En otro notebook se hace un análisis de la cantidad de estados y transiciones de estados encontradas, viendo los grafos resultantes de ejecutar cada herramienta con sus distintas configuraciones posibles.

# %% [markdown]
# ##### 0. Setup

# %%
import json5 as json
import pandas as pd

# %% [markdown]
# ##### 1. Importo los resultados (formato JSON) y los guardo en dataframes de pandas.

# %%
with open('../results/benchmarks/echidna_benchmark1_times') as file:
    echidna_times_benchmark_1 = json.load(file)
    df_echidna_1 = pd.DataFrame.from_dict(echidna_times_benchmark_1)

with open('../results/benchmarks/verisol_benchmark1_times') as file:
    verisol_times_benchmark_1 = json.load(file)
    df_verisol_1 = pd.DataFrame.from_dict(verisol_times_benchmark_1)
    df_verisol_1.insert(4, 'reduce combinations', True)

with open('../results/benchmarks/echidna_benchmark2_times') as file:
    echidna_times_benchmark_2 = json.load(file)
    df_echidna_2 = pd.DataFrame.from_dict(echidna_times_benchmark_2)

with open('../results/benchmarks/verisol_benchmark2_times') as file:
    verisol_times_benchmark_2 = json.load(file)
    df_verisol_2 = pd.DataFrame.from_dict(verisol_times_benchmark_2)
    df_verisol_2.insert(4, 'reduce combinations', True)

# %% [markdown]
# ##### 2. Defino algunas funciones que voy a usar para manipular las dataframes y hacer que los resultados sean más fáciles de leer.

# %%
df_echidna_2
# Out:
#          contract  test_limit mode  reduce combinations  time_in_s
# 0         Auction        1000    e                False      14.71
# 1    Crowdfunding        1000    e                False       8.61
# 2    Crowdfunding        1000    s                False       9.86
# 3    EPXCrowdsale        1000    e                False      91.62
# 4    EPXCrowdsale        1000    s                False      13.61
# ..            ...         ...  ...                  ...        ...
# 109  EPXCrowdsale       50000    e                 True      96.87
# 110  EPXCrowdsale      500000    e                 True     403.60
# 111  Crowdfunding        1000    e                 True      10.94
# 112  Crowdfunding       50000    e                 True      31.60
# 113  Crowdfunding      500000    e                 True     229.73
#
# [114 rows x 5 columns]

# %%
def agregar_columnas(df):
    """ Le agregamos las columnas donde se van a guardar los tiempos de cada ejecución para cada contrato. """
    for mode in ['Epa', 'States']:
        for tx_bound in [4, 8]:
            df[f'Ver {mode} Time {tx_bound}'] = None

    for mode in ['Epa', 'States']:
        for test_limit in [1000, 50000, 500000]:
            df[f'Ech {mode} Time {test_limit}'] = None

# %%
def ordenar_resultados_echidna(df_joined, df_nueva):
    for index, row in df_joined.iterrows():
        contract = row['contract']
        test_limit = row['test_limit']
        mode = row['mode_e']
        time_in_s = row['time_in_s_e']
        
        
        if test_limit == 1000:
            if mode == 'e':
                df_nueva.at[index, 'Ech Epa Time 1000'] = time_in_s
            elif mode == 's':
                df_nueva.at[index, 'Ech States Time 1000'] = time_in_s
        elif test_limit == 50000:
            if mode == 'e':
                df_nueva.at[index, 'Ech Epa Time 50000'] = time_in_s
            elif mode == 's':
                df_nueva.at[index, 'Ech States Time 50000'] = time_in_s
        elif test_limit == 500000:
            if mode == 'e':
                df_nueva.at[index, 'Ech Epa Time 500000'] = time_in_s
            elif mode == 's':
                df_nueva.at[index, 'Ech States Time 500000'] = time_in_s
        elif test_limit == 1000000:
            if mode == 'e':
                df_nueva.at[index, 'Ech Epa Time 1000000'] = time_in_s
            elif mode == 's':
                df_nueva.at[index, 'Ech States Time 1000000'] = time_in_s
        else:
            print(f"Contract: {contract}")
            print(f"Test Limit: {test_limit}")
            print(f"Mode: {mode}")
            print(f"Time in s: {time_in_s}")
            df_nueva.at[index, 'EXTRA'] = time_in_s
            # raise Exception(f'El test_limit ({test_limit}) no matcheó con ninguno de los valores esperados...')

    df_nueva.drop(columns=['mode_e', 'test_limit', 'time_in_s_e'], inplace=True)

# %%
def ordenar_resultados_verisol(df_joined, df_nueva):
    for index, row in df_joined.iterrows():
        contract = row['contract']
        tx_bound = row['txBound']
        mode = row['mode_v']
        time_in_s = row['time_in_s_v']
        
        if tx_bound == 4:
            if mode == 'e':
                df_nueva.at[index, 'Ver Epa Time 4'] = time_in_s
            elif mode == 's':
                df_nueva.at[index, 'Ver States Time 4'] = time_in_s
        elif tx_bound == 8:
            if mode == 'e':
                df_nueva.at[index, 'Ver Epa Time 8'] = time_in_s
            elif mode == 's':
                df_nueva.at[index, 'Ver States Time 8'] = time_in_s
        else:
            print(f"Contract: {contract}")
            print(f"Tx Bound: {tx_bound}")
            print(f"Mode: {mode}")
            print(f"Time in s: {time_in_s}")
            df_nueva.at[index, 'EXTRA'] = time_in_s
            raise Exception(f'El txBound ({tx_bound}) no matcheó con ninguno de los valores esperados...')
    
    df_nueva.drop(columns=['mode_v', 'txBound', 'time_in_s_v', 'timeout', 'reduce combinations_v'], inplace=True)

# %% [markdown]
# ##### 3. Aplico las funciones sobre los dataframes.

# %%
def process(df_echidna, df_verisol):

    # Hacemos un outer join para unir los dos dataframes por el campo 'contract.
    df_joined_temp = pd.merge(df_verisol, df_echidna, on='contract', how='outer', suffixes=('_v', '_e'))

    # Le agregamos las columnas donde se van a guardar los tiempos de cada ejecución para cada contrato.
    agregar_columnas(df_joined_temp)

    # Buscamos los resultados de entre todas las filas y los metemos en la columna que le corresponde.
    df_joined = df_joined_temp
    ordenar_resultados_echidna(df_joined_temp, df_joined)
    ordenar_resultados_verisol(df_joined_temp, df_joined)

    df_joined_grouped_by_contract = df_joined.groupby(['contract', 'reduce combinations_e'])
    df_joined_grouped_by_contract = df_joined_grouped_by_contract.first()
    # df_joined_grouped_by_contract.head()
    return df_joined_grouped_by_contract

# %%
df_joined_grouped_by_contract_1 = process(df_echidna_1, df_verisol_1)
df_joined_grouped_by_contract_2 = process(df_echidna_2, df_verisol_2)

# %%
df_joined_grouped_by_contract_2
# Out:
#                                                       Ver Epa Time 4
# contract                        reduce combinations_e
# Auction                         False                           3.12  \
#                                 True                            3.12
# AuctionEnded                    False                           40.3
#                                 True                            40.3
# AuctionWithdraw                 False                           67.9
#                                 True                            67.9
# Crowdfunding                    False                          56.67
#                                 True                           56.67
# CrowdfundingTime_Base           False                          39.45
#                                 True                           39.45
# CrowdfundingTime_BaseBalance    False                         142.92
#                                 True                          142.92
# CrowdfundingTime_BaseBalanceFix False                         133.18
#                                 True                          133.18
# EPXCrowdsale                    False                         111.15
#                                 True                          111.15
# EPXCrowdsaleIsCrowdsaleClosed   False                         260.88
#                                 True                          260.88
# EscrowVault                     False                           87.0
#                                 True                            87.0
# RefundEscrow                    False                          67.18
#                                 True                           67.18
# RefundEscrowWithdraw            False                         162.39
#                                 True                          162.39
# RockPaperScissors               False                           33.0
#                                 True                            33.0
# SimpleAuction                   False                           2.34
#                                 True                            2.34
# SimpleAuctionEnded              False                          128.9
#                                 True                           128.9
# SimpleAuctionHB                 False                           None
# SimpleAuctionTime               False                         180.16
#                                 True                          180.16
#
#                                                       Ver Epa Time 8
# contract                        reduce combinations_e
# Auction                         False                           2.06  \
#                                 True                            2.06
# AuctionEnded                    False                          40.25
#                                 True                           40.25
# AuctionWithdraw                 False                          69.77
#                                 True                           69.77
# Crowdfunding                    False                          45.94
#                                 True                           45.94
# CrowdfundingTime_Base           False                          37.07
#                                 True                           37.07
# CrowdfundingTime_BaseBalance    False                        1350.96
#                                 True                         1350.96
# CrowdfundingTime_BaseBalanceFix False                         132.31
#                                 True                          132.31
# EPXCrowdsale                    False                         305.58
#                                 True                          305.58
# EPXCrowdsaleIsCrowdsaleClosed   False                         814.31
#                                 True                          814.31
# EscrowVault                     False                          98.76
#                                 True                           98.76
# RefundEscrow                    False                          63.37
#                                 True                           63.37
# RefundEscrowWithdraw            False                         150.53
#                                 True                          150.53
# RockPaperScissors               False                          33.07
#                                 True                           33.07
# SimpleAuction                   False                           2.11
#                                 True                            2.11
# SimpleAuctionEnded              False                          129.3
#                                 True                           129.3
# SimpleAuctionHB                 False                           None
# SimpleAuctionTime               False                         182.82
#                                 True                          182.82
#
#                                                       Ver States Time 4
# contract                        reduce combinations_e
# Auction                         False                              None  \
#                                 True                               None
# AuctionEnded                    False                              None
#                                 True                               None
# AuctionWithdraw                 False                              None
#                                 True                               None
# Crowdfunding                    False                             28.96
#                                 True                              28.96
# CrowdfundingTime_Base           False                              None
#                                 True                               None
# CrowdfundingTime_BaseBalance    False                              None
#                                 True                               None
# CrowdfundingTime_BaseBalanceFix False                              None
#                                 True                               None
# EPXCrowdsale                    False                            323.75
#                                 True                             323.75
# EPXCrowdsaleIsCrowdsaleClosed   False                              None
#                                 True                               None
# EscrowVault                     False                            114.95
#                                 True                             114.95
# RefundEscrow                    False                             55.34
#                                 True                              55.34
# RefundEscrowWithdraw            False                              None
#                                 True                               None
# RockPaperScissors               False                            100.16
#                                 True                             100.16
# SimpleAuction                   False                              None
#                                 True                               None
# SimpleAuctionEnded              False                              None
#                                 True                               None
# SimpleAuctionHB                 False                            131.77
# SimpleAuctionTime               False                              None
#                                 True                               None
#
#                                                       Ver States Time 8
# contract                        reduce combinations_e
# Auction                         False                              None  \
#                                 True                               None
# AuctionEnded                    False                              None
#                                 True                               None
# AuctionWithdraw                 False                              None
#                                 True                               None
# Crowdfunding                    False                              28.2
#                                 True                               28.2
# CrowdfundingTime_Base           False                              None
#                                 True                               None
# CrowdfundingTime_BaseBalance    False                              None
#                                 True                               None
# CrowdfundingTime_BaseBalanceFix False                              None
#                                 True                               None
# EPXCrowdsale                    False                           5447.05
#                                 True                            5447.05
# EPXCrowdsaleIsCrowdsaleClosed   False                              None
#                                 True                               None
# EscrowVault                     False                            114.99
#                                 True                             114.99
# RefundEscrow                    False                             52.33
#                                 True                              52.33
# RefundEscrowWithdraw            False                              None
#                                 True                               None
# RockPaperScissors               False                             99.28
#                                 True                              99.28
# SimpleAuction                   False                              None
#                                 True                               None
# SimpleAuctionEnded              False                              None
#                                 True                               None
# SimpleAuctionHB                 False                            264.34
# SimpleAuctionTime               False                              None
#                                 True                               None
#
#                                                       Ech Epa Time 1000
# contract                        reduce combinations_e
# Auction                         False                             14.71  \
#                                 True                               7.52
# AuctionEnded                    False                             43.46
#                                 True                                6.9
# AuctionWithdraw                 False                             50.93
#                                 True                               6.79
# Crowdfunding                    False                              8.61
#                                 True                              10.94
# CrowdfundingTime_Base           False                             16.58
#                                 True                              10.86
# CrowdfundingTime_BaseBalance    False                            416.47
#                                 True                              47.22
# CrowdfundingTime_BaseBalanceFix False                            428.74
#                                 True                              61.09
# EPXCrowdsale                    False                             91.62
#                                 True                              59.63
# EPXCrowdsaleIsCrowdsaleClosed   False                            497.36
#                                 True                             183.86
# EscrowVault                     False                            168.02
#                                 True                              21.72
# RefundEscrow                    False                             29.51
#                                 True                              13.25
# RefundEscrowWithdraw            False                            183.11
#                                 True                              27.39
# RockPaperScissors               False                               9.5
#                                 True                              10.38
# SimpleAuction                   False                              8.93
#                                 True                               5.13
# SimpleAuctionEnded              False                             41.75
#                                 True                               7.27
# SimpleAuctionHB                 False                              None
# SimpleAuctionTime               False                             13.84
#                                 True                               5.82
#
#                                                       Ech Epa Time 50000
# contract                        reduce combinations_e
# Auction                         False                              41.96  \
#                                 True                               17.41
# AuctionEnded                    False                             187.72
#                                 True                               19.18
# AuctionWithdraw                 False                             207.65
#                                 True                               19.95
# Crowdfunding                    False                              37.02
#                                 True                                31.6
# CrowdfundingTime_Base           False                              62.43
#                                 True                                28.3
# CrowdfundingTime_BaseBalance    False                            1285.64
#                                 True                               88.13
# CrowdfundingTime_BaseBalanceFix False                             1306.9
#                                 True                               95.89
# EPXCrowdsale                    False                             443.36
#                                 True                               96.87
# EPXCrowdsaleIsCrowdsaleClosed   False                            1951.03
#                                 True                              221.91
# EscrowVault                     False                            1300.67
#                                 True                               84.66
# RefundEscrow                    False                             209.31
#                                 True                               53.17
# RefundEscrowWithdraw            False                            1108.78
#                                 True                               118.8
# RockPaperScissors               False                              44.37
#                                 True                               28.45
# SimpleAuction                   False                              43.15
#                                 True                               17.48
# SimpleAuctionEnded              False                             222.24
#                                 True                               20.85
# SimpleAuctionHB                 False                               None
# SimpleAuctionTime               False                              61.79
#                                 True                                19.0
#
#                                                       Ech Epa Time 500000
# contract                        reduce combinations_e
# Auction                         False                              291.16  \
#                                 True                               126.89
# AuctionEnded                    False                             1415.04
#                                 True                               130.94
# AuctionWithdraw                 False                             1573.73
#                                 True                               139.96
# Crowdfunding                    False                              296.77
#                                 True                               229.73
# CrowdfundingTime_Base           False                              469.38
#                                 True                               186.89
# CrowdfundingTime_BaseBalance    False                             9115.68
#                                 True                               447.48
# CrowdfundingTime_BaseBalanceFix False                             9377.87
#                                 True                               391.08
# EPXCrowdsale                    False                             3814.16
#                                 True                                403.6
# EPXCrowdsaleIsCrowdsaleClosed   False                            16253.27
#                                 True                               619.11
# EscrowVault                     False                             11851.1
#                                 True                               664.75
# RefundEscrow                    False                              1783.9
#                                 True                               426.01
# RefundEscrowWithdraw            False                             9938.97
#                                 True                               977.72
# RockPaperScissors               False                              362.27
#                                 True                               185.15
# SimpleAuction                   False                              333.24
#                                 True                               131.72
# SimpleAuctionEnded              False                             1759.46
#                                 True                               148.19
# SimpleAuctionHB                 False                                None
# SimpleAuctionTime               False                              494.77
#                                 True                               146.93
#
#                                                       Ech States Time 1000
# contract                        reduce combinations_e
# Auction                         False                                 None  \
#                                 True                                  None
# AuctionEnded                    False                                 None
#                                 True                                  None
# AuctionWithdraw                 False                                 None
#                                 True                                  None
# Crowdfunding                    False                                 9.86
#                                 True                                  None
# CrowdfundingTime_Base           False                                 None
#                                 True                                  None
# CrowdfundingTime_BaseBalance    False                                 None
#                                 True                                  None
# CrowdfundingTime_BaseBalanceFix False                                 None
#                                 True                                  None
# EPXCrowdsale                    False                                13.61
#                                 True                                  None
# EPXCrowdsaleIsCrowdsaleClosed   False                                 None
#                                 True                                  None
# EscrowVault                     False                                 7.88
#                                 True                                  None
# RefundEscrow                    False                                 5.41
#                                 True                                  None
# RefundEscrowWithdraw            False                                 None
#                                 True                                  None
# RockPaperScissors               False                                 8.36
#                                 True                                  None
# SimpleAuction                   False                                 None
#                                 True                                  None
# SimpleAuctionEnded              False                                 None
#                                 True                                  None
# SimpleAuctionHB                 False                                 8.74
# SimpleAuctionTime               False                                 None
#                                 True                                  None
#
#                                                       Ech States Time 50000
# contract                        reduce combinations_e
# Auction                         False                                  None  \
#                                 True                                   None
# AuctionEnded                    False                                  None
#                                 True                                   None
# AuctionWithdraw                 False                                  None
#                                 True                                   None
# Crowdfunding                    False                                 35.67
#                                 True                                   None
# CrowdfundingTime_Base           False                                  None
#                                 True                                   None
# CrowdfundingTime_BaseBalance    False                                  None
#                                 True                                   None
# CrowdfundingTime_BaseBalanceFix False                                  None
#                                 True                                   None
# EPXCrowdsale                    False                                 96.82
#                                 True                                   None
# EPXCrowdsaleIsCrowdsaleClosed   False                                  None
#                                 True                                   None
# EscrowVault                     False                                 60.21
#                                 True                                   None
# RefundEscrow                    False                                 34.06
#                                 True                                   None
# RefundEscrowWithdraw            False                                  None
#                                 True                                   None
# RockPaperScissors               False                                 43.95
#                                 True                                   None
# SimpleAuction                   False                                  None
#                                 True                                   None
# SimpleAuctionEnded              False                                  None
#                                 True                                   None
# SimpleAuctionHB                 False                                 57.96
# SimpleAuctionTime               False                                  None
#                                 True                                   None
#
#                                                       Ech States Time 500000
# contract                        reduce combinations_e
# Auction                         False                                   None
#                                 True                                    None
# AuctionEnded                    False                                   None
#                                 True                                    None
# AuctionWithdraw                 False                                   None
#                                 True                                    None
# Crowdfunding                    False                                 267.84
#                                 True                                    None
# CrowdfundingTime_Base           False                                   None
#                                 True                                    None
# CrowdfundingTime_BaseBalance    False                                   None
#                                 True                                    None
# CrowdfundingTime_BaseBalanceFix False                                   None
#                                 True                                    None
# EPXCrowdsale                    False                                 913.58
#                                 True                                    None
# EPXCrowdsaleIsCrowdsaleClosed   False                                   None
#                                 True                                    None
# EscrowVault                     False                                 507.71
#                                 True                                    None
# RefundEscrow                    False                                 284.69
#                                 True                                    None
# RefundEscrowWithdraw            False                                   None
#                                 True                                    None
# RockPaperScissors               False                                 356.21
#                                 True                                    None
# SimpleAuction                   False                                   None
#                                 True                                    None
# SimpleAuctionEnded              False                                   None
#                                 True                                    None
# SimpleAuctionHB                 False                                 472.67
# SimpleAuctionTime               False                                   None
#                                 True                                    None

# %%
df_epa_1 = df_joined_grouped_by_contract_1.filter(regex='Epa')

# De states tal vez tenemos 2 resultados de ejecuciones iguales (porque el reduceCombinations nunca se ejecuta).
# Por eso calculamos el mean. 
df_states_1 = df_joined_grouped_by_contract_1.filter(regex='States')
df_states_1 = df_states_1.groupby(['contract']).mean()


# Round the float values of both dataframes to 2 decimals
df_epa_1 = df_epa_1.applymap(lambda x: round(x, 2) if isinstance(x, float) else x)
df_states_1 = df_states_1.applymap(lambda x: round(x, 2) if isinstance(x, float) else x)

# %%
df_epa_2 = df_joined_grouped_by_contract_2.filter(regex='Epa')

# De states tenemos 2 resultados de ejecuciones iguales (porque el reduceCombinations nunca se ejecuta).
# Por eso calculamos el mean. 
df_states_2 = df_joined_grouped_by_contract_2.filter(regex='States')
df_states_2 = df_states_2.groupby(['contract']).mean()


# Round the float values of both dataframes to 2 decimals
df_epa_2 = df_epa_2.applymap(lambda x: round(x, 2) if isinstance(x, float) else x)
df_states_2 = df_states_2.applymap(lambda x: round(x, 2) if isinstance(x, float) else x)

# %%
# Remove column Ech Epa Time 1000000 from df_epa_2 and from df_states_2
# First check if the column exists
if 'Ech Epa Time 1000000' in df_epa_2.columns:
    df_epa_2.drop(columns=['Ech Epa Time 1000000'], inplace=True)

if 'Ech States Time 1000000' in df_states_2.columns:
    df_states_2.drop(columns=['Ech States Time 1000000'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Remove column Ech Epa Time 1000000 from df_epa_2 and from df_states_2
# ----> 2 df_epa_2.drop(columns=['Ech Epa Time 1000000'], inplace=True)
#       3 df_states_2.drop(columns=['Ech States Time 1000000'], inplace=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/frame.py:5268, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5120 def drop(
#    5121     self,
#    5122     labels: IndexLabel = None,
#    (...)
#    5129     errors: IgnoreRaise = "raise",
#    5130 ) -> DataFrame | None:
#    5131     """
#    5132     Drop specified labels from rows or columns.
#    5133
#    (...)
#    5266             weight  1.0     0.8
#    5267     """
# -> 5268     return super().drop(
#    5269         labels=labels,
#    5270         axis=axis,
#    5271         index=index,
#    5272         columns=columns,
#    5273         level=level,
#    5274         inplace=inplace,
#    5275         errors=errors,
#    5276     )
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexes/base.py:6696, in Index.drop(self, labels, errors)
#    6694 if mask.any():
#    6695     if errors != "ignore":
# -> 6696         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6697     indexer = indexer[~mask]
#    6698 return self.delete(indexer)
#
# KeyError: "['Ech Epa Time 1000000'] not found in axis"

# %%
df_epa_2
# Out:
#                                                        Ver Epa Time 4
# contract                        reduce combinations_e
# Auction                         False                            3.12  \
#                                 True                             3.12
# AuctionEnded                    False                           40.30
#                                 True                            40.30
# AuctionWithdraw                 False                           67.90
#                                 True                            67.90
# Crowdfunding                    False                           56.67
#                                 True                            56.67
# CrowdfundingTime_Base           False                           39.45
#                                 True                            39.45
# CrowdfundingTime_BaseBalance    False                          142.92
#                                 True                           142.92
# CrowdfundingTime_BaseBalanceFix False                          133.18
#                                 True                           133.18
# EPXCrowdsale                    False                          111.15
#                                 True                           111.15
# EPXCrowdsaleIsCrowdsaleClosed   False                          260.88
#                                 True                           260.88
# EscrowVault                     False                           87.00
#                                 True                            87.00
# RefundEscrow                    False                           67.18
#                                 True                            67.18
# RefundEscrowWithdraw            False                          162.39
#                                 True                           162.39
# RockPaperScissors               False                           33.00
#                                 True                            33.00
# SimpleAuction                   False                            2.34
#                                 True                             2.34
# SimpleAuctionEnded              False                          128.90
#                                 True                           128.90
# SimpleAuctionHB                 False                             NaN
# SimpleAuctionTime               False                          180.16
#                                 True                           180.16
#
#                                                        Ver Epa Time 8
# contract                        reduce combinations_e
# Auction                         False                            2.06  \
#                                 True                             2.06
# AuctionEnded                    False                           40.25
#                                 True                            40.25
# AuctionWithdraw                 False                           69.77
#                                 True                            69.77
# Crowdfunding                    False                           45.94
#                                 True                            45.94
# CrowdfundingTime_Base           False                           37.07
#                                 True                            37.07
# CrowdfundingTime_BaseBalance    False                         1350.96
#                                 True                          1350.96
# CrowdfundingTime_BaseBalanceFix False                          132.31
#                                 True                           132.31
# EPXCrowdsale                    False                          305.58
#                                 True                           305.58
# EPXCrowdsaleIsCrowdsaleClosed   False                          814.31
#                                 True                           814.31
# EscrowVault                     False                           98.76
#                                 True                            98.76
# RefundEscrow                    False                           63.37
#                                 True                            63.37
# RefundEscrowWithdraw            False                          150.53
#                                 True                           150.53
# RockPaperScissors               False                           33.07
#                                 True                            33.07
# SimpleAuction                   False                            2.11
#                                 True                             2.11
# SimpleAuctionEnded              False                          129.30
#                                 True                           129.30
# SimpleAuctionHB                 False                             NaN
# SimpleAuctionTime               False                          182.82
#                                 True                           182.82
#
#                                                        Ech Epa Time 1000
# contract                        reduce combinations_e
# Auction                         False                              14.71  \
#                                 True                                7.52
# AuctionEnded                    False                              43.46
#                                 True                                6.90
# AuctionWithdraw                 False                              50.93
#                                 True                                6.79
# Crowdfunding                    False                               8.61
#                                 True                               10.94
# CrowdfundingTime_Base           False                              16.58
#                                 True                               10.86
# CrowdfundingTime_BaseBalance    False                             416.47
#                                 True                               47.22
# CrowdfundingTime_BaseBalanceFix False                             428.74
#                                 True                               61.09
# EPXCrowdsale                    False                              91.62
#                                 True                               59.63
# EPXCrowdsaleIsCrowdsaleClosed   False                             497.36
#                                 True                              183.86
# EscrowVault                     False                             168.02
#                                 True                               21.72
# RefundEscrow                    False                              29.51
#                                 True                               13.25
# RefundEscrowWithdraw            False                             183.11
#                                 True                               27.39
# RockPaperScissors               False                               9.50
#                                 True                               10.38
# SimpleAuction                   False                               8.93
#                                 True                                5.13
# SimpleAuctionEnded              False                              41.75
#                                 True                                7.27
# SimpleAuctionHB                 False                                NaN
# SimpleAuctionTime               False                              13.84
#                                 True                                5.82
#
#                                                        Ech Epa Time 50000
# contract                        reduce combinations_e
# Auction                         False                               41.96  \
#                                 True                                17.41
# AuctionEnded                    False                              187.72
#                                 True                                19.18
# AuctionWithdraw                 False                              207.65
#                                 True                                19.95
# Crowdfunding                    False                               37.02
#                                 True                                31.60
# CrowdfundingTime_Base           False                               62.43
#                                 True                                28.30
# CrowdfundingTime_BaseBalance    False                             1285.64
#                                 True                                88.13
# CrowdfundingTime_BaseBalanceFix False                             1306.90
#                                 True                                95.89
# EPXCrowdsale                    False                              443.36
#                                 True                                96.87
# EPXCrowdsaleIsCrowdsaleClosed   False                             1951.03
#                                 True                               221.91
# EscrowVault                     False                             1300.67
#                                 True                                84.66
# RefundEscrow                    False                              209.31
#                                 True                                53.17
# RefundEscrowWithdraw            False                             1108.78
#                                 True                               118.80
# RockPaperScissors               False                               44.37
#                                 True                                28.45
# SimpleAuction                   False                               43.15
#                                 True                                17.48
# SimpleAuctionEnded              False                              222.24
#                                 True                                20.85
# SimpleAuctionHB                 False                                 NaN
# SimpleAuctionTime               False                               61.79
#                                 True                                19.00
#
#                                                        Ech Epa Time 500000
# contract                        reduce combinations_e
# Auction                         False                               291.16
#                                 True                                126.89
# AuctionEnded                    False                              1415.04
#                                 True                                130.94
# AuctionWithdraw                 False                              1573.73
#                                 True                                139.96
# Crowdfunding                    False                               296.77
#                                 True                                229.73
# CrowdfundingTime_Base           False                               469.38
#                                 True                                186.89
# CrowdfundingTime_BaseBalance    False                              9115.68
#                                 True                                447.48
# CrowdfundingTime_BaseBalanceFix False                              9377.87
#                                 True                                391.08
# EPXCrowdsale                    False                              3814.16
#                                 True                                403.60
# EPXCrowdsaleIsCrowdsaleClosed   False                             16253.27
#                                 True                                619.11
# EscrowVault                     False                             11851.10
#                                 True                                664.75
# RefundEscrow                    False                              1783.90
#                                 True                                426.01
# RefundEscrowWithdraw            False                              9938.97
#                                 True                                977.72
# RockPaperScissors               False                               362.27
#                                 True                                185.15
# SimpleAuction                   False                               333.24
#                                 True                                131.72
# SimpleAuctionEnded              False                              1759.46
#                                 True                                148.19
# SimpleAuctionHB                 False                                  NaN
# SimpleAuctionTime               False                               494.77
#                                 True                                146.93

# %% [markdown]
# ##### 4. Exporto los resultados.

# %%
containing_dir = '../results/tables'

df_epa_1.to_csv(f'{containing_dir}/benchmark1_times_epa.csv')
df_states_1.to_csv(f'{containing_dir}/benchmark1_times_states.csv')

df_epa_2.to_csv(f'{containing_dir}/benchmark2_times_epa.csv')
df_states_2.to_csv(f'{containing_dir}/benchmark2_times_states.csv')
